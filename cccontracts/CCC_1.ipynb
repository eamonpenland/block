# %% [markdown]
# # Compiled Steps

# %% [markdown]
# ## Similarities Amid Smart Contracts

# %% [markdown]
# Everyday new smart contracts are published to Ethereum’s blockchain. Some contracts perform routine functions and simple exchanges while others initiate complex iterative processes or fulfill contractual obligations between parties. Smart contracts are also subject to multiple forms of attack. This project, ‘Compiled Steps’ is a tool to quantify the smart contract landscape through edit distance analysis which, I think, is a step towards understanding vulnerabilities, use case variability, and uniqueness.

# %%
import Levenshtein as lv

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import time

# %%
data = pd.read_csv('Levdist_contracts_avail.csv' , quoting = 2)
data
# Out:
#           Contract Name  distance =0  0 < distance< 100  100 < distance < 1000
# 0                Ballot          7.0                1.0                    3.0
# 1         Blind Auction          0.0                0.0                    0.0
# 2  Safe Remote Purchase          0.0                0.0                 5137.0
# 3        Simple Auction          1.0                0.0                 6761.0
# 4                  Coin         94.0                1.0                 8815.0
# 5             Crowdsale          4.0                0.0                   29.0
# 6               Greeter        127.0               47.0                 9183.0
# 7                Mortal          7.0               48.0                 8669.0
# 8                 Token          0.0             2728.0                 5965.0

# %%
cccdata = pd.read_csv('bytecode_ccc.csv')

#print(cccdata)

#listcccdata = list(cccdata)
print(cccdata.values)
#print(listcccdata)
# Out:
# [['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']
#  ['...']]

# %% [markdown]
# import csv
#
# with open('bytecode_ccc.csv', 'r') as f:
#   reader = csv.reader(f)
#   your_list = list(reader)
#
# print(your_list)

# %% [markdown]
# data.hist(bins=10)
#
# plt.title("Data")
# plt.xlabel("fruits")
# plt.ylabel("Frequency")
# plt.show()

# %%
a = '...'
b = '...'
c = '...'
d = '...'
f = '...'
g = '...'

# %% [markdown]
# ## Distance between duplicate contracts

# %%
lv.distance ('...','...')
# Out:
# 0

# %% [markdown]
# ## Distance between dissimilar contracts

# %%
lv.distance('...', '...')
# Out:
# 12127

# %% [markdown]
# ## Distance between similar contracts

# %%
lv.distance(a,b)
# Out:
# 225

# %%
lv.ratio(a,b)
# Out:
# 0.9526169092598328

# %%
lv.distance(g,f)
# Out:
# 0

# %%
lv.ratio(g,f)
# Out:
# 1.0

# %% [markdown]
# ## Similarity Matrix

# %%
def distance_matrix(str_list):
    
    dist_matrix = np.zeros(shape=(len(str_list), len(str_list)))
    t0 = time.time()
    
    
   
    for i in range(0, len(str_list)):
        print i
        for j in range(i+1, len(str_list)):
                dist_matrix[i][j] = lv.distance(str_list[i], str_list[j]) 
    for i in range(0, len(str_list)):
        for j in range(0, len(str_list)):
            if i == j:
                dist_matrix[i][j] = 0 
            elif i > j:
                dist_matrix[i][j] = dist_matrix[j][i]
    t1 = time.time()
    print "took", (t1-t0), "seconds"
    return dist_matrix


str_list = cccdata
#str_list = ['...','...', '...']

distance_matrix(str_list)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-ad756d557210> in <module>()
#      24 #str_list = ['...','...', '...']
#      25
# ---> 26 distance_matrix(str_list)
#
# <ipython-input-34-ad756d557210> in distance_matrix(str_list)
#       9         print i
#      10         for j in range(i+1, len(str_list)):
# ---> 11                 dist_matrix[i][j] = lv.distance(str_list[i], str_list[j])
#      12     for i in range(0, len(str_list)):
#      13         for j in range(0, len(str_list)):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
